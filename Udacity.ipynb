# %%
import requests

#Fetch a webpage
read = requests.get('https://news.ycombinator.com/')
print(read.text)
# Out:
# <html lang="en" op="news"><head><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width, initial-scale=1.0"><link rel="stylesheet" type="text/css" href="news.css?AStQiYo2DN2Cck12gbjP">
#         <link rel="shortcut icon" href="favicon.ico">
#           <link rel="alternate" type="application/rss+xml" title="RSS" href="rss">
#         <title>Hacker News</title></head><body><center><table id="hnmain" border="0" cellpadding="0" cellspacing="0" width="85%" bgcolor="#f6f6ef">
#         <tr><td bgcolor="#ff6600"><table border="0" cellpadding="0" cellspacing="0" width="100%" style="padding:2px"><tr><td style="width:18px;padding-right:4px"><a href="https://news.ycombinator.com"><img src="y18.gif" width="18" height="18" style="border:1px white solid;"></a></td>
#                   <td style="line-height:12pt; height:10px;"><span class="pagetop"><b class="hnname"><a href="news">Hacker News</a></b>
# ...

# %%
import re

#Remove HTML Tags using RegEx
pattern = re.compile(r"<.*?>")  # Tags look like <....>
print(pattern.sub('',read.text))   #Replace them with blank
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | past | comments | ask | show | jobs | submit
#                               login
#
#
#
#
#       1.      Show HN: How to X with Y. Engineering questions, answered (howtoxwithy.com)
#         42 points by alex_portabella 3 hours ago  | hide | 38&nbsp;comments
#
#
#       2.      Hacking together a USB-C charger for a cheap Chromebook (filippo.io)
#         97 points by laktak 4 hours ago  | hide | 36&nbsp;comments
#
#
#       3.      Meetings should not be held with phones present – Dutch intelligence officer (nu.nl)
#         172 points by jacquesm 2 hours ago  | hide | 81&nbsp;comments
#
#
#       4.      No, Microsoft is not rebasing Windows to Linux (boxofcables.dev)
#         90 points by sunbum 1 hour ago  | hide | 76&nbsp;comments
#
#
#       5.      Microsoft Uses Trademark Law to Disrupt Trickbot Botnet (krebsonsecurity.com)
# ...

# %%
from bs4 import BeautifulSoup

#Removing HTML tags using Beautiful Soup Library
soup =  BeautifulSoup(read.text,"html5lib")
print(soup.get_text())
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | past | comments | ask | show | jobs | submit
#                               login
#
#
#
#
#       1.      Show HN: How to X with Y. Engineering questions, answered (howtoxwithy.com)
#         42 points by alex_portabella 3 hours ago  | hide | 38 comments
#
#
#       2.      Hacking together a USB-C charger for a cheap Chromebook (filippo.io)
#         97 points by laktak 4 hours ago  | hide | 36 comments
#
#
#       3.      Meetings should not be held with phones present – Dutch intelligence officer (nu.nl)
#         172 points by jacquesm 2 hours ago  | hide | 81 comments
#
#
#       4.      No, Microsoft is not rebasing Windows to Linux (boxofcables.dev)
#         90 points by sunbum 1 hour ago  | hide | 76 comments
#
#
#       5.      Microsoft Uses Trademark Law to Disrupt Trickbot Botnet (krebsonsecurity.com)
#         11 points by todsacerdoti 45 minutes ago  | hide | 2 comments
#
#
# ...

# %%
# Find all course summaries

sumi = soup.find_all("td", class_="storylink")
sumi[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-0164cc92a8b0> in <module>
#       2
#       3 sumi = soup.find_all("td", class_="storylink")
# ----> 4 sumi[0]
#
# IndexError: list index out of range
